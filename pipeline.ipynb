# %%
import papermill as pm
import os

# %%
# add executed_notebooks folder
os.makedirs('executed_notebooks', exist_ok=True)

# %%
# run ML model
pm.execute_notebook(
    'notebooks/MLmodel.ipynb',
    'executed_notebooks/MLmodel.ipynb')

# %%
# %%capture
# %run notebooks/Sector_LinearRegression.ipynb

# %%
# %%capture
pm.execute_notebook(
    'notebooks/top 10 pick code.ipynb',
    'executed_notebooks/top 10 pick code.ipynb',
    kernel_name='python3'
    )

# %%
# %run notebooks/backtest.ipynb
# Out:
# [*********************100%***********************]  10 of 10 completed
# [*********************100%***********************]  10 of 10 completed
# [*********************100%***********************]  10 of 10 completed
# [*********************100%***********************]  10 of 10 completed
# [*********************100%***********************]  10 of 10 completed
# [*********************100%***********************]  10 of 10 completed
# [*********************100%***********************]  10 of 10 completed
# [*********************100%***********************]  10 of 10 completed
# [*********************100%***********************]  10 of 10 completed
# [*********************100%***********************]  10 of 10 completed
# Backtest results for period: 2015-04-24_to_2017-04-24
# Sharpe Ratio: 1.2485
# Max Drawdown: -0.1936
# Backtest results for period: 2013-10-09_to_2015-10-08
# Sharpe Ratio: 0.9856
# Max Drawdown: -0.1189
# Backtest results for period: 2012-07-06_to_2014-07-09
# Sharpe Ratio: 1.4747
# Max Drawdown: -0.1143
# Backtest results for period: 2016-07-05_to_2018-07-03
# Sharpe Ratio: 2.0192
# Max Drawdown: -0.1070
# Backtest results for period: 2016-11-22_to_2018-11-21
# Sharpe Ratio: 1.4121
# Max Drawdown: -0.1483
# Backtest results for period: 2015-11-23_to_2017-11-21
# Sharpe Ratio: 1.5604
# Max Drawdown: -0.1857
# Backtest results for period: 2011-05-12_to_2013-05-14
# Sharpe Ratio: 0.8131
# Max Drawdown: -0.2097
# Backtest results for period: 2010-11-17_to_2012-11-17
# Sharpe Ratio: 0.4261
# Max Drawdown: -0.2097
# Backtest results for period: 2016-08-19_to_2018-08-20
# Sharpe Ratio: 1.7854
# Max Drawdown: -0.1070
# Backtest results for period: 2015-05-15_to_2017-05-15
# Sharpe Ratio: 1.2583
# Max Drawdown: -0.1936
#                           Sharpe ratio  max drawdown
# 2015-04-24_to_2017-04-24      1.248469     -0.193592
# 2013-10-09_to_2015-10-08      0.985621     -0.118907
# 2012-07-06_to_2014-07-09      1.474749     -0.114303
# 2016-07-05_to_2018-07-03      2.019180     -0.107006
# 2016-11-22_to_2018-11-21      1.412141     -0.148263
# 2015-11-23_to_2017-11-21      1.560367     -0.185735
# 2011-05-12_to_2013-05-14      0.813132     -0.209690
# 2010-11-17_to_2012-11-17      0.426078     -0.209690
# 2016-08-19_to_2018-08-20      1.785393     -0.107006
# 2015-05-15_to_2017-05-15      1.258311     -0.193592
#
# Median Sharpe Ratio across all periods: 1.3352
# Median Max Drawdown across all periods: -0.1670
#
# Backtest summary:
#                      period  sharpe_ratio  max_drawdown
# 0  2015-04-24_to_2017-04-24      1.248469     -0.193592
# 1  2013-10-09_to_2015-10-08      0.985621     -0.118907
# 2  2012-07-06_to_2014-07-09      1.474749     -0.114303
# 3  2016-07-05_to_2018-07-03      2.019180     -0.107006
# 4  2016-11-22_to_2018-11-21      1.412141     -0.148263
# 5  2015-11-23_to_2017-11-21      1.560367     -0.185735
# 6  2011-05-12_to_2013-05-14      0.813132     -0.209690
# 7  2010-11-17_to_2012-11-17      0.426078     -0.209690
# 8  2016-08-19_to_2018-08-20      1.785393     -0.107006
# 9  2015-05-15_to_2017-05-15      1.258311     -0.193592
