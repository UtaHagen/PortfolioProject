# %%
#importing the libraries

import pandas as pd
import yfinance as yf
import numpy as np

# %%
port_pick = pd.read_csv('Data/portfolio_pick.csv')['Stock'].tolist()

# %%
def fetch_high_volatility_tickers(ticker_list, threshold=0.1):
    high_vol_tickers = []
    vol_data = {}

    for ticker in ticker_list:
        try:
            stock_data = yf.download(ticker, period="1y", interval="1d", progress=False)
            
            if stock_data.empty:
                print(f"No data found for {ticker}.")
                continue

            closing_prices = stock_data['Close']
            std_dev = np.std(closing_prices)
            mean_price = np.mean(closing_prices)

            vol_data[ticker] = {
                "std_dev": std_dev,
                "mean_price": mean_price,
                "std_dev_pct": std_dev / mean_price if mean_price > 0 else 0
            }

            if vol_data[ticker]["std_dev_pct"] >= threshold:
                high_vol_tickers.append(ticker)

            print(f"Processed {ticker}: Std Dev = {std_dev:.2f}, Mean Price = {mean_price:.2f}, Std Dev % = {std_dev / mean_price:.2%}")

        except Exception as e:
            print(f"Error processing {ticker}: {e}")

    return high_vol_tickers, vol_data


vol_tickers = port_pick
threshold = 0.1

high_vol_tickers, vol_data = fetch_high_volatility_tickers(port_pick, threshold)

print("\nTickers with standard deviation >= 10%:")
for ticker in high_vol_tickers:
    print(f"{ticker}: Std Dev % = {vol_data[ticker]['std_dev_pct']:.2%}")
# Out:
# Processed EBAY: Std Dev = 7.42, Mean Price = 54.32, Std Dev % = 13.67%
# Processed CMG: Std Dev = 5.55, Mean Price = 56.91, Std Dev % = 9.75%
# Processed EXPE: Std Dev = 20.07, Mean Price = 141.82, Std Dev % = 14.15%
# Processed F: Std Dev = 1.02, Mean Price = 11.70, Std Dev % = 8.75%
# Processed GM: Std Dev = 5.55, Mean Price = 45.32, Std Dev % = 12.24%
# Processed HD: Std Dev = 27.87, Mean Price = 369.05, Std Dev % = 7.55%
# Processed MAR: Std Dev = 18.78, Mean Price = 246.08, Std Dev % = 7.63%
# Processed PG: Std Dev = 7.46, Mean Price = 164.66, Std Dev % = 4.53%
# Processed DG: Std Dev = 27.64, Mean Price = 118.56, Std Dev % = 23.32%
# Processed XOM: Std Dev = 6.80, Mean Price = 113.35, Std Dev % = 6.00%
# Processed AXP: Std Dev = 31.49, Mean Price = 241.59, Std Dev % = 13.03%
# Processed BAC: Std Dev = 3.90, Mean Price = 38.99, Std Dev % = 10.00%
# Processed BLK: Std Dev = 92.97, Mean Price = 861.54, Std Dev % = 10.79%
# Processed FIS: Std Dev = 8.64, Mean Price = 75.68, Std Dev % = 11.42%
# Processed GS: Std Dev = 66.20, Mean Price = 464.92, Std Dev % = 14.24%
# Processed MS: Std Dev = 13.69, Mean Price = 101.18, Std Dev % = 13.53%
# Processed USB: Std Dev = 3.65, Mean Price = 43.93, Std Dev % = 8.31%
# Processed WFC: Std Dev = 6.95, Mean Price = 58.61, Std Dev % = 11.86%
# Processed BDX: Std Dev = 5.90, Mean Price = 235.39, Std Dev % = 2.51%
# Processed BIIB: Std Dev = 27.44, Mean Price = 209.58, Std Dev % = 13.09%
# Processed ELV: Std Dev = 49.11, Mean Price = 496.77, Std Dev % = 9.89%
# Processed PFE: Std Dev = 1.35, Mean Price = 27.94, Std Dev % = 4.83%
# Processed LMT: Std Dev = 55.91, Mean Price = 495.54, Std Dev % = 11.28%
# Processed AMT: Std Dev = 16.96, Mean Price = 204.65, Std Dev % = 8.29%
# Processed ACN: Std Dev = 27.02, Mean Price = 339.63, Std Dev % = 7.95%
# Processed ADI: Std Dev = 16.71, Mean Price = 212.84, Std Dev % = 7.85%
# Processed AMD: Std Dev = 17.47, Mean Price = 158.14, Std Dev % = 11.05%
# Processed CRM: Std Dev = 30.11, Mean Price = 281.09, Std Dev % = 10.71%
# Processed MU: Std Dev = 16.84, Mean Price = 105.77, Std Dev % = 15.92%
# Processed NXPI: Std Dev = 19.67, Mean Price = 242.25, Std Dev % = 8.12%
# Processed QCOM: Std Dev = 19.25, Mean Price = 170.76, Std Dev % = 11.28%
#
# Tickers with standard deviation >= 10%:
# EBAY: Std Dev % = 13.67%
# EXPE: Std Dev % = 14.15%
# GM: Std Dev % = 12.24%
# DG: Std Dev % = 23.32%
# AXP: Std Dev % = 13.03%
# BAC: Std Dev % = 10.00%
# BLK: Std Dev % = 10.79%
# FIS: Std Dev % = 11.42%
# GS: Std Dev % = 14.24%
# MS: Std Dev % = 13.53%
# WFC: Std Dev % = 11.86%
# BIIB: Std Dev % = 13.09%
# LMT: Std Dev % = 11.28%
# AMD: Std Dev % = 11.05%
# CRM: Std Dev % = 10.71%
# MU: Std Dev % = 15.92%
# QCOM: Std Dev % = 11.28%

# %%
def fetch_options_data(ticker_list):
    options_data = {}

    for ticker in ticker_list:
        try:
            stock = yf.Ticker(ticker)
            
            expiration_dates = stock.options
            
            ticker_data = {"calls": [], "puts": []}
            
            for date in expiration_dates:
                opt_chain = stock.option_chain(date)
                
                ticker_data["calls"].append({"expiration_date": date, "data": opt_chain.calls})
                ticker_data["puts"].append({"expiration_date": date, "data": opt_chain.puts})
            
            options_data[ticker] = ticker_data
            print(f"Fetched options data for {ticker}")
        
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")
    
    return options_data



options_list = high_vol_tickers

all_options_data = fetch_options_data(options_list)
# Out:
# Fetched options data for EBAY
# Fetched options data for EXPE
# Fetched options data for GM
# Fetched options data for DG
# Fetched options data for AXP
# Fetched options data for BAC
# Fetched options data for BLK
# Fetched options data for FIS
# Fetched options data for GS
# Fetched options data for MS
# Fetched options data for WFC
# Fetched options data for BIIB
# Fetched options data for LMT
# Fetched options data for AMD
# Fetched options data for CRM
# Fetched options data for MU
# Fetched options data for QCOM

# %%
def analyze_strangle_profit(ticker, std_dev, current_price):
    try:
        stock = yf.Ticker(ticker)
        expiration_dates = stock.options
        
        results = []

        for date in expiration_dates[:1]:  # only look at the first expiration date
            opt_chain = stock.option_chain(date)
            calls = opt_chain.calls
            puts = opt_chain.puts
            
            # for strangle, we should:
            # 1. buy call option with strike price higher than the current price
            # 2. buy put option with strike price lower than the current price
            otm_calls = calls[calls['strike'] > current_price]  # out of the money call
            otm_puts = puts[puts['strike'] < current_price]     # out of the money put
            
            for _, call in otm_calls.iterrows():
                for _, put in otm_puts.iterrows():
                    strike_price_call = call['strike']
                    strike_price_put = put['strike']
                    call_price = call['lastPrice']
                    put_price = put['lastPrice']
                    strangle_cost = call_price + put_price
                    
                    # upward profit = stock price increase above call strike price - strangle cost
                    upward_profit = max(0, (current_price + std_dev - strike_price_call) - strangle_cost)
                    
                    # downward profit = stock price decrease below put strike price - strangle cost
                    downward_profit = max(0, (strike_price_put - (current_price - std_dev)) - strangle_cost)
                    
                    if (upward_profit > 0) and (downward_profit > 0):
                        results.append({
                            "call_strike": strike_price_call,
                            "put_strike": strike_price_put, 
                            "call_price": call_price,
                            "put_price": put_price,
                            "strangle_cost": strangle_cost,
                            "upward_profit": upward_profit,
                            "downward_profit": downward_profit,
                            "meets_criteria": True
                        })
        
        return results

    except Exception as e:
        print(f"Error analyzing {ticker}: {e}")
        return []

def find_profitable_strangles(ticker_list, threshold=0.1):
    profitable_strangles = {}
    
    for ticker in ticker_list:
        try:
            stock_data = yf.download(ticker, period="1y", interval="1d", progress=False)
            closing_prices = stock_data['Close']
            std_dev = np.std(closing_prices)
            current_price = closing_prices.iloc[-1]

            if std_dev / current_price >= threshold:
                results = analyze_strangle_profit(ticker, std_dev, current_price)
                if results:
                    profitable_strangles[ticker] = results

        except Exception as e:
            print(f"Error processing {ticker}: {e}")

    return profitable_strangles


port_pick = high_vol_tickers
threshold = 0.1
profitable_strangles = find_profitable_strangles(port_pick, threshold)

for ticker, strangles in profitable_strangles.items():
    print(f"\nProfitable Strangles for {ticker}:")
    for s in strangles:
        print(s)
# Out:
# Profitable Strangles for EBAY:
# {'call_strike': 66.0, 'put_strike': 59.0, 'call_price': 0.36, 'put_price': 0.05, 'strangle_cost': 0.41, 'upward_profit': 6.0241171061082746, 'downward_profit': 1.0041128336473373, 'meets_criteria': True}
# {'call_strike': 66.0, 'put_strike': 60.0, 'call_price': 0.36, 'put_price': 0.12, 'strangle_cost': 0.48, 'upward_profit': 5.954117106108274, 'downward_profit': 1.9341128336473372, 'meets_criteria': True}
# {'call_strike': 66.0, 'put_strike': 61.0, 'call_price': 0.36, 'put_price': 0.05, 'strangle_cost': 0.41, 'upward_profit': 6.0241171061082746, 'downward_profit': 3.004112833647337, 'meets_criteria': True}
# {'call_strike': 66.0, 'put_strike': 62.0, 'call_price': 0.36, 'put_price': 0.12, 'strangle_cost': 0.48, 'upward_profit': 5.954117106108274, 'downward_profit': 3.934112833647337, 'meets_criteria': True}
# {'call_strike': 66.0, 'put_strike': 63.0, 'call_price': 0.36, 'put_price': 0.27, 'strangle_cost': 0.63, 'upward_profit': 5.804117106108275, 'downward_profit': 4.784112833647337, 'meets_criteria': True}
# {'call_strike': 66.0, 'put_strike': 64.0, 'call_price': 0.36, 'put_price': 0.48, 'strangle_cost': 0.84, 'upward_profit': 5.594117106108275, 'downward_profit': 5.574112833647337, 'meets_criteria': True}
# {'call_strike': 66.0, 'put_strike': 65.0, 'call_price': 0.36, 'put_price': 0.74, 'strangle_cost': 1.1, 'upward_profit': 5.334117106108275, 'downward_profit': 6.3141128336473376, 'meets_criteria': True}
# {'call_strike': 67.0, 'put_strike': 58.0, 'call_price': 0.15, 'put_price': 0.25, 'strangle_cost': 0.4, 'upward_profit': 5.034117106108274, 'downward_profit': 0.014112833647337175, 'meets_criteria': True}
# {'call_strike': 67.0, 'put_strike': 59.0, 'call_price': 0.15, 'put_price': 0.05, 'strangle_cost': 0.2, 'upward_profit': 5.2341171061082745, 'downward_profit': 1.2141128336473372, 'meets_criteria': True}
# {'call_strike': 67.0, 'put_strike': 60.0, 'call_price': 0.15, 'put_price': 0.12, 'strangle_cost': 0.27, 'upward_profit': 5.164117106108275, 'downward_profit': 2.144112833647337, 'meets_criteria': True}
# {'call_strike': 67.0, 'put_strike': 61.0, 'call_price': 0.15, 'put_price': 0.05, 'strangle_cost': 0.2, 'upward_profit': 5.2341171061082745, 'downward_profit': 3.214112833647337, 'meets_criteria': True}
# {'call_strike': 67.0, 'put_strike': 62.0, 'call_price': 0.15, 'put_price': 0.12, 'strangle_cost': 0.27, 'upward_profit': 5.164117106108275, 'downward_profit': 4.144112833647338, 'meets_criteria': True}
# {'call_strike': 67.0, 'put_strike': 63.0, 'call_price': 0.15, 'put_price': 0.27, 'strangle_cost': 0.42000000000000004, 'upward_profit': 5.014117106108275, 'downward_profit': 4.994112833647337, 'meets_criteria': True}
# {'call_strike': 67.0, 'put_strike': 64.0, 'call_price': 0.15, 'put_price': 0.48, 'strangle_cost': 0.63, 'upward_profit': 4.804117106108275, 'downward_profit': 5.784112833647337, 'meets_criteria': True}
# {'call_strike': 67.0, 'put_strike': 65.0, 'call_price': 0.15, 'put_price': 0.74, 'strangle_cost': 0.89, 'upward_profit': 4.544117106108275, 'downward_profit': 6.5241128336473375, 'meets_criteria': True}
# {'call_strike': 68.0, 'put_strike': 58.0, 'call_price': 0.08, 'put_price': 0.25, 'strangle_cost': 0.33, 'upward_profit': 4.104117106108275, 'downward_profit': 0.08411283364733718, 'meets_criteria': True}
# {'call_strike': 68.0, 'put_strike': 59.0, 'call_price': 0.08, 'put_price': 0.05, 'strangle_cost': 0.13, 'upward_profit': 4.304117106108275, 'downward_profit': 1.2841128336473373, 'meets_criteria': True}
# {'call_strike': 68.0, 'put_strike': 60.0, 'call_price': 0.08, 'put_price': 0.12, 'strangle_cost': 0.2, 'upward_profit': 4.2341171061082745, 'downward_profit': 2.214112833647337, 'meets_criteria': True}
# {'call_strike': 68.0, 'put_strike': 61.0, 'call_price': 0.08, 'put_price': 0.05, 'strangle_cost': 0.13, 'upward_profit': 4.304117106108275, 'downward_profit': 3.2841128336473373, 'meets_criteria': True}
# {'call_strike': 68.0, 'put_strike': 62.0, 'call_price': 0.08, 'put_price': 0.12, 'strangle_cost': 0.2, 'upward_profit': 4.2341171061082745, 'downward_profit': 4.214112833647337, 'meets_criteria': True}
# {'call_strike': 68.0, 'put_strike': 63.0, 'call_price': 0.08, 'put_price': 0.27, 'strangle_cost': 0.35000000000000003, 'upward_profit': 4.084117106108275, 'downward_profit': 5.0641128336473376, 'meets_criteria': True}
# {'call_strike': 68.0, 'put_strike': 64.0, 'call_price': 0.08, 'put_price': 0.48, 'strangle_cost': 0.5599999999999999, 'upward_profit': 3.8741171061082746, 'downward_profit': 5.854112833647338, 'meets_criteria': True}
# {'call_strike': 68.0, 'put_strike': 65.0, 'call_price': 0.08, 'put_price': 0.74, 'strangle_cost': 0.82, 'upward_profit': 3.614117106108275, 'downward_profit': 6.594112833647337, 'meets_criteria': True}
# {'call_strike': 69.0, 'put_strike': 58.0, 'call_price': 0.12, 'put_price': 0.25, 'strangle_cost': 0.37, 'upward_profit': 3.0641171061082746, 'downward_profit': 0.0441128336473372, 'meets_criteria': True}
# {'call_strike': 69.0, 'put_strike': 59.0, 'call_price': 0.12, 'put_price': 0.05, 'strangle_cost': 0.16999999999999998, 'upward_profit': 3.2641171061082748, 'downward_profit': 1.2441128336473373, 'meets_criteria': True}
# {'call_strike': 69.0, 'put_strike': 60.0, 'call_price': 0.12, 'put_price': 0.12, 'strangle_cost': 0.24, 'upward_profit': 3.1941171061082745, 'downward_profit': 2.174112833647337, 'meets_criteria': True}
# {'call_strike': 69.0, 'put_strike': 61.0, 'call_price': 0.12, 'put_price': 0.05, 'strangle_cost': 0.16999999999999998, 'upward_profit': 3.2641171061082748, 'downward_profit': 3.2441128336473373, 'meets_criteria': True}
# {'call_strike': 69.0, 'put_strike': 62.0, 'call_price': 0.12, 'put_price': 0.12, 'strangle_cost': 0.24, 'upward_profit': 3.1941171061082745, 'downward_profit': 4.174112833647337, 'meets_criteria': True}
# {'call_strike': 69.0, 'put_strike': 63.0, 'call_price': 0.12, 'put_price': 0.27, 'strangle_cost': 0.39, 'upward_profit': 3.0441171061082746, 'downward_profit': 5.0241128336473375, 'meets_criteria': True}
# {'call_strike': 69.0, 'put_strike': 64.0, 'call_price': 0.12, 'put_price': 0.48, 'strangle_cost': 0.6, 'upward_profit': 2.8341171061082746, 'downward_profit': 5.8141128336473376, 'meets_criteria': True}
# {'call_strike': 69.0, 'put_strike': 65.0, 'call_price': 0.12, 'put_price': 0.74, 'strangle_cost': 0.86, 'upward_profit': 2.574117106108275, 'downward_profit': 6.554112833647337, 'meets_criteria': True}
# {'call_strike': 70.0, 'put_strike': 58.0, 'call_price': 0.03, 'put_price': 0.25, 'strangle_cost': 0.28, 'upward_profit': 2.1541171061082744, 'downward_profit': 0.13411283364733717, 'meets_criteria': True}
# {'call_strike': 70.0, 'put_strike': 59.0, 'call_price': 0.03, 'put_price': 0.05, 'strangle_cost': 0.08, 'upward_profit': 2.3541171061082746, 'downward_profit': 1.3341128336473371, 'meets_criteria': True}
# {'call_strike': 70.0, 'put_strike': 60.0, 'call_price': 0.03, 'put_price': 0.12, 'strangle_cost': 0.15, 'upward_profit': 2.284117106108275, 'downward_profit': 2.2641128336473373, 'meets_criteria': True}
# {'call_strike': 70.0, 'put_strike': 61.0, 'call_price': 0.03, 'put_price': 0.05, 'strangle_cost': 0.08, 'upward_profit': 2.3541171061082746, 'downward_profit': 3.334112833647337, 'meets_criteria': True}
# {'call_strike': 70.0, 'put_strike': 62.0, 'call_price': 0.03, 'put_price': 0.12, 'strangle_cost': 0.15, 'upward_profit': 2.284117106108275, 'downward_profit': 4.264112833647337, 'meets_criteria': True}
# {'call_strike': 70.0, 'put_strike': 63.0, 'call_price': 0.03, 'put_price': 0.27, 'strangle_cost': 0.30000000000000004, 'upward_profit': 2.134117106108275, 'downward_profit': 5.114112833647337, 'meets_criteria': True}
# {'call_strike': 70.0, 'put_strike': 64.0, 'call_price': 0.03, 'put_price': 0.48, 'strangle_cost': 0.51, 'upward_profit': 1.9241171061082747, 'downward_profit': 5.904112833647337, 'meets_criteria': True}
# {'call_strike': 70.0, 'put_strike': 65.0, 'call_price': 0.03, 'put_price': 0.74, 'strangle_cost': 0.77, 'upward_profit': 1.6641171061082747, 'downward_profit': 6.644112833647338, 'meets_criteria': True}
# {'call_strike': 71.0, 'put_strike': 58.0, 'call_price': 0.15, 'put_price': 0.25, 'strangle_cost': 0.4, 'upward_profit': 1.0341171061082748, 'downward_profit': 0.014112833647337175, 'meets_criteria': True}
# {'call_strike': 71.0, 'put_strike': 59.0, 'call_price': 0.15, 'put_price': 0.05, 'strangle_cost': 0.2, 'upward_profit': 1.2341171061082747, 'downward_profit': 1.2141128336473372, 'meets_criteria': True}
# {'call_strike': 71.0, 'put_strike': 60.0, 'call_price': 0.15, 'put_price': 0.12, 'strangle_cost': 0.27, 'upward_profit': 1.1641171061082747, 'downward_profit': 2.144112833647337, 'meets_criteria': True}
# {'call_strike': 71.0, 'put_strike': 61.0, 'call_price': 0.15, 'put_price': 0.05, 'strangle_cost': 0.2, 'upward_profit': 1.2341171061082747, 'downward_profit': 3.214112833647337, 'meets_criteria': True}
# {'call_strike': 71.0, 'put_strike': 62.0, 'call_price': 0.15, 'put_price': 0.12, 'strangle_cost': 0.27, 'upward_profit': 1.1641171061082747, 'downward_profit': 4.144112833647338, 'meets_criteria': True}
# {'call_strike': 71.0, 'put_strike': 63.0, 'call_price': 0.15, 'put_price': 0.27, 'strangle_cost': 0.42000000000000004, 'upward_profit': 1.0141171061082748, 'downward_profit': 4.994112833647337, 'meets_criteria': True}
# {'call_strike': 71.0, 'put_strike': 64.0, 'call_price': 0.15, 'put_price': 0.48, 'strangle_cost': 0.63, 'upward_profit': 0.8041171061082747, 'downward_profit': 5.784112833647337, 'meets_criteria': True}
# {'call_strike': 71.0, 'put_strike': 65.0, 'call_price': 0.15, 'put_price': 0.74, 'strangle_cost': 0.89, 'upward_profit': 0.5441171061082747, 'downward_profit': 6.5241128336473375, 'meets_criteria': True}
#
# Profitable Strangles for EXPE:
# {'call_strike': 185.0, 'put_strike': 167.5, 'call_price': 2.46, 'put_price': 0.24, 'strangle_cost': 2.7, 'upward_profit': 17.124569018225674, 'downward_profit': 0.12456901822567357, 'meets_criteria': True}
# {'call_strike': 185.0, 'put_strike': 170.0, 'call_price': 2.46, 'put_price': 0.34, 'strangle_cost': 2.8, 'upward_profit': 17.024569018225673, 'downward_profit': 2.524569018225674, 'meets_criteria': True}
# {'call_strike': 185.0, 'put_strike': 172.5, 'call_price': 2.46, 'put_price': 0.39, 'strangle_cost': 2.85, 'upward_profit': 16.974569018225672, 'downward_profit': 4.974569018225674, 'meets_criteria': True}
# {'call_strike': 185.0, 'put_strike': 175.0, 'call_price': 2.46, 'put_price': 0.18, 'strangle_cost': 2.64, 'upward_profit': 17.184569018225673, 'downward_profit': 7.684569018225673, 'meets_criteria': True}
# {'call_strike': 185.0, 'put_strike': 177.5, 'call_price': 2.46, 'put_price': 0.44, 'strangle_cost': 2.9, 'upward_profit': 16.924569018225675, 'downward_profit': 9.924569018225673, 'meets_criteria': True}
# {'call_strike': 185.0, 'put_strike': 180.0, 'call_price': 2.46, 'put_price': 0.71, 'strangle_cost': 3.17, 'upward_profit': 16.654569018225672, 'downward_profit': 12.154569018225674, 'meets_criteria': True}
# {'call_strike': 185.0, 'put_strike': 182.5, 'call_price': 2.46, 'put_price': 1.49, 'strangle_cost': 3.95, 'upward_profit': 15.874569018225674, 'downward_profit': 13.874569018225674, 'meets_criteria': True}
# {'call_strike': 187.5, 'put_strike': 167.5, 'call_price': 1.38, 'put_price': 0.24, 'strangle_cost': 1.6199999999999999, 'upward_profit': 15.704569018225675, 'downward_profit': 1.2045690182256739, 'meets_criteria': True}
# {'call_strike': 187.5, 'put_strike': 170.0, 'call_price': 1.38, 'put_price': 0.34, 'strangle_cost': 1.72, 'upward_profit': 15.604569018225673, 'downward_profit': 3.604569018225674, 'meets_criteria': True}
# {'call_strike': 187.5, 'put_strike': 172.5, 'call_price': 1.38, 'put_price': 0.39, 'strangle_cost': 1.77, 'upward_profit': 15.554569018225674, 'downward_profit': 6.054569018225674, 'meets_criteria': True}
# {'call_strike': 187.5, 'put_strike': 175.0, 'call_price': 1.38, 'put_price': 0.18, 'strangle_cost': 1.5599999999999998, 'upward_profit': 15.764569018225673, 'downward_profit': 8.764569018225673, 'meets_criteria': True}
# {'call_strike': 187.5, 'put_strike': 177.5, 'call_price': 1.38, 'put_price': 0.44, 'strangle_cost': 1.8199999999999998, 'upward_profit': 15.504569018225673, 'downward_profit': 11.004569018225673, 'meets_criteria': True}
# {'call_strike': 187.5, 'put_strike': 180.0, 'call_price': 1.38, 'put_price': 0.71, 'strangle_cost': 2.09, 'upward_profit': 15.234569018225674, 'downward_profit': 13.234569018225674, 'meets_criteria': True}
# {'call_strike': 187.5, 'put_strike': 182.5, 'call_price': 1.38, 'put_price': 1.49, 'strangle_cost': 2.87, 'upward_profit': 14.454569018225673, 'downward_profit': 14.954569018225673, 'meets_criteria': True}
# {'call_strike': 190.0, 'put_strike': 167.5, 'call_price': 0.65, 'put_price': 0.24, 'strangle_cost': 0.89, 'upward_profit': 13.934569018225673, 'downward_profit': 1.9345690182256736, 'meets_criteria': True}
# {'call_strike': 190.0, 'put_strike': 170.0, 'call_price': 0.65, 'put_price': 0.34, 'strangle_cost': 0.99, 'upward_profit': 13.834569018225674, 'downward_profit': 4.3345690182256735, 'meets_criteria': True}
# {'call_strike': 190.0, 'put_strike': 172.5, 'call_price': 0.65, 'put_price': 0.39, 'strangle_cost': 1.04, 'upward_profit': 13.784569018225675, 'downward_profit': 6.784569018225674, 'meets_criteria': True}
# {'call_strike': 190.0, 'put_strike': 175.0, 'call_price': 0.65, 'put_price': 0.18, 'strangle_cost': 0.8300000000000001, 'upward_profit': 13.994569018225674, 'downward_profit': 9.494569018225674, 'meets_criteria': True}
# {'call_strike': 190.0, 'put_strike': 177.5, 'call_price': 0.65, 'put_price': 0.44, 'strangle_cost': 1.09, 'upward_profit': 13.734569018225674, 'downward_profit': 11.734569018225674, 'meets_criteria': True}
# {'call_strike': 190.0, 'put_strike': 180.0, 'call_price': 0.65, 'put_price': 0.71, 'strangle_cost': 1.3599999999999999, 'upward_profit': 13.464569018225674, 'downward_profit': 13.964569018225674, 'meets_criteria': True}
# {'call_strike': 190.0, 'put_strike': 182.5, 'call_price': 0.65, 'put_price': 1.49, 'strangle_cost': 2.14, 'upward_profit': 12.684569018225673, 'downward_profit': 15.684569018225673, 'meets_criteria': True}
# {'call_strike': 192.5, 'put_strike': 167.5, 'call_price': 0.27, 'put_price': 0.24, 'strangle_cost': 0.51, 'upward_profit': 11.814569018225674, 'downward_profit': 2.314569018225674, 'meets_criteria': True}
# {'call_strike': 192.5, 'put_strike': 170.0, 'call_price': 0.27, 'put_price': 0.34, 'strangle_cost': 0.6100000000000001, 'upward_profit': 11.714569018225674, 'downward_profit': 4.714569018225673, 'meets_criteria': True}
# {'call_strike': 192.5, 'put_strike': 172.5, 'call_price': 0.27, 'put_price': 0.39, 'strangle_cost': 0.66, 'upward_profit': 11.664569018225674, 'downward_profit': 7.164569018225674, 'meets_criteria': True}
# {'call_strike': 192.5, 'put_strike': 175.0, 'call_price': 0.27, 'put_price': 0.18, 'strangle_cost': 0.45, 'upward_profit': 11.874569018225674, 'downward_profit': 9.874569018225674, 'meets_criteria': True}
# {'call_strike': 192.5, 'put_strike': 177.5, 'call_price': 0.27, 'put_price': 0.44, 'strangle_cost': 0.71, 'upward_profit': 11.614569018225673, 'downward_profit': 12.114569018225673, 'meets_criteria': True}
# {'call_strike': 192.5, 'put_strike': 180.0, 'call_price': 0.27, 'put_price': 0.71, 'strangle_cost': 0.98, 'upward_profit': 11.344569018225673, 'downward_profit': 14.344569018225673, 'meets_criteria': True}
# {'call_strike': 192.5, 'put_strike': 182.5, 'call_price': 0.27, 'put_price': 1.49, 'strangle_cost': 1.76, 'upward_profit': 10.564569018225674, 'downward_profit': 16.064569018225672, 'meets_criteria': True}
# {'call_strike': 195.0, 'put_strike': 167.5, 'call_price': 0.16, 'put_price': 0.24, 'strangle_cost': 0.4, 'upward_profit': 9.424569018225673, 'downward_profit': 2.424569018225674, 'meets_criteria': True}
# {'call_strike': 195.0, 'put_strike': 170.0, 'call_price': 0.16, 'put_price': 0.34, 'strangle_cost': 0.5, 'upward_profit': 9.324569018225674, 'downward_profit': 4.824569018225674, 'meets_criteria': True}
# {'call_strike': 195.0, 'put_strike': 172.5, 'call_price': 0.16, 'put_price': 0.39, 'strangle_cost': 0.55, 'upward_profit': 9.274569018225673, 'downward_profit': 7.274569018225674, 'meets_criteria': True}
# {'call_strike': 195.0, 'put_strike': 175.0, 'call_price': 0.16, 'put_price': 0.18, 'strangle_cost': 0.33999999999999997, 'upward_profit': 9.484569018225674, 'downward_profit': 9.984569018225674, 'meets_criteria': True}
# {'call_strike': 195.0, 'put_strike': 177.5, 'call_price': 0.16, 'put_price': 0.44, 'strangle_cost': 0.6, 'upward_profit': 9.224569018225674, 'downward_profit': 12.224569018225674, 'meets_criteria': True}
# {'call_strike': 195.0, 'put_strike': 180.0, 'call_price': 0.16, 'put_price': 0.71, 'strangle_cost': 0.87, 'upward_profit': 8.954569018225675, 'downward_profit': 14.454569018225675, 'meets_criteria': True}
# {'call_strike': 195.0, 'put_strike': 182.5, 'call_price': 0.16, 'put_price': 1.49, 'strangle_cost': 1.65, 'upward_profit': 8.174569018225673, 'downward_profit': 16.174569018225675, 'meets_criteria': True}
# {'call_strike': 197.5, 'put_strike': 167.5, 'call_price': 0.33, 'put_price': 0.24, 'strangle_cost': 0.5700000000000001, 'upward_profit': 6.7545690182256735, 'downward_profit': 2.2545690182256735, 'meets_criteria': True}
# {'call_strike': 197.5, 'put_strike': 170.0, 'call_price': 0.33, 'put_price': 0.34, 'strangle_cost': 0.67, 'upward_profit': 6.654569018225674, 'downward_profit': 4.654569018225674, 'meets_criteria': True}
# {'call_strike': 197.5, 'put_strike': 172.5, 'call_price': 0.33, 'put_price': 0.39, 'strangle_cost': 0.72, 'upward_profit': 6.604569018225674, 'downward_profit': 7.104569018225674, 'meets_criteria': True}
# {'call_strike': 197.5, 'put_strike': 175.0, 'call_price': 0.33, 'put_price': 0.18, 'strangle_cost': 0.51, 'upward_profit': 6.814569018225674, 'downward_profit': 9.814569018225674, 'meets_criteria': True}
# {'call_strike': 197.5, 'put_strike': 177.5, 'call_price': 0.33, 'put_price': 0.44, 'strangle_cost': 0.77, 'upward_profit': 6.554569018225674, 'downward_profit': 12.054569018225674, 'meets_criteria': True}
# {'call_strike': 197.5, 'put_strike': 180.0, 'call_price': 0.33, 'put_price': 0.71, 'strangle_cost': 1.04, 'upward_profit': 6.284569018225674, 'downward_profit': 14.284569018225675, 'meets_criteria': True}
# {'call_strike': 197.5, 'put_strike': 182.5, 'call_price': 0.33, 'put_price': 1.49, 'strangle_cost': 1.82, 'upward_profit': 5.5045690182256735, 'downward_profit': 16.004569018225673, 'meets_criteria': True}
# {'call_strike': 200.0, 'put_strike': 167.5, 'call_price': 0.32, 'put_price': 0.24, 'strangle_cost': 0.56, 'upward_profit': 4.264569018225673, 'downward_profit': 2.2645690182256737, 'meets_criteria': True}
# {'call_strike': 200.0, 'put_strike': 170.0, 'call_price': 0.32, 'put_price': 0.34, 'strangle_cost': 0.66, 'upward_profit': 4.164569018225674, 'downward_profit': 4.664569018225674, 'meets_criteria': True}
# {'call_strike': 200.0, 'put_strike': 172.5, 'call_price': 0.32, 'put_price': 0.39, 'strangle_cost': 0.71, 'upward_profit': 4.114569018225674, 'downward_profit': 7.114569018225674, 'meets_criteria': True}
# {'call_strike': 200.0, 'put_strike': 175.0, 'call_price': 0.32, 'put_price': 0.18, 'strangle_cost': 0.5, 'upward_profit': 4.324569018225674, 'downward_profit': 9.824569018225674, 'meets_criteria': True}
# {'call_strike': 200.0, 'put_strike': 177.5, 'call_price': 0.32, 'put_price': 0.44, 'strangle_cost': 0.76, 'upward_profit': 4.064569018225674, 'downward_profit': 12.064569018225674, 'meets_criteria': True}
# {'call_strike': 200.0, 'put_strike': 180.0, 'call_price': 0.32, 'put_price': 0.71, 'strangle_cost': 1.03, 'upward_profit': 3.7945690182256735, 'downward_profit': 14.294569018225674, 'meets_criteria': True}
# {'call_strike': 200.0, 'put_strike': 182.5, 'call_price': 0.32, 'put_price': 1.49, 'strangle_cost': 1.81, 'upward_profit': 3.0145690182256737, 'downward_profit': 16.014569018225675, 'meets_criteria': True}
# {'call_strike': 202.5, 'put_strike': 167.5, 'call_price': 0.26, 'put_price': 0.24, 'strangle_cost': 0.5, 'upward_profit': 1.8245690182256737, 'downward_profit': 2.3245690182256737, 'meets_criteria': True}
# {'call_strike': 202.5, 'put_strike': 170.0, 'call_price': 0.26, 'put_price': 0.34, 'strangle_cost': 0.6000000000000001, 'upward_profit': 1.7245690182256737, 'downward_profit': 4.724569018225674, 'meets_criteria': True}
# {'call_strike': 202.5, 'put_strike': 172.5, 'call_price': 0.26, 'put_price': 0.39, 'strangle_cost': 0.65, 'upward_profit': 1.6745690182256738, 'downward_profit': 7.174569018225673, 'meets_criteria': True}
# {'call_strike': 202.5, 'put_strike': 175.0, 'call_price': 0.26, 'put_price': 0.18, 'strangle_cost': 0.44, 'upward_profit': 1.8845690182256738, 'downward_profit': 9.884569018225674, 'meets_criteria': True}
# {'call_strike': 202.5, 'put_strike': 177.5, 'call_price': 0.26, 'put_price': 0.44, 'strangle_cost': 0.7, 'upward_profit': 1.6245690182256738, 'downward_profit': 12.124569018225674, 'meets_criteria': True}
# {'call_strike': 202.5, 'put_strike': 180.0, 'call_price': 0.26, 'put_price': 0.71, 'strangle_cost': 0.97, 'upward_profit': 1.3545690182256738, 'downward_profit': 14.354569018225673, 'meets_criteria': True}
# {'call_strike': 202.5, 'put_strike': 182.5, 'call_price': 0.26, 'put_price': 1.49, 'strangle_cost': 1.75, 'upward_profit': 0.5745690182256737, 'downward_profit': 16.074569018225674, 'meets_criteria': True}
#
# Profitable Strangles for GM:
# {'call_strike': 52.0, 'put_strike': 47.0, 'call_price': 0.65, 'put_price': 0.04, 'strangle_cost': 0.6900000000000001, 'upward_profit': 4.666128854840079, 'downward_profit': 0.046126108258048304, 'meets_criteria': True}
# {'call_strike': 52.0, 'put_strike': 47.5, 'call_price': 0.65, 'put_price': 0.13, 'strangle_cost': 0.78, 'upward_profit': 4.576128854840079, 'downward_profit': 0.45612610825804834, 'meets_criteria': True}
# {'call_strike': 52.0, 'put_strike': 48.0, 'call_price': 0.65, 'put_price': 0.06, 'strangle_cost': 0.71, 'upward_profit': 4.64612885484008, 'downward_profit': 1.0261261082580484, 'meets_criteria': True}
# {'call_strike': 52.0, 'put_strike': 48.5, 'call_price': 0.65, 'put_price': 0.1, 'strangle_cost': 0.75, 'upward_profit': 4.60612885484008, 'downward_profit': 1.4861261082580484, 'meets_criteria': True}
# {'call_strike': 52.0, 'put_strike': 49.0, 'call_price': 0.65, 'put_price': 0.11, 'strangle_cost': 0.76, 'upward_profit': 4.59612885484008, 'downward_profit': 1.9761261082580484, 'meets_criteria': True}
# {'call_strike': 52.0, 'put_strike': 49.5, 'call_price': 0.65, 'put_price': 0.15, 'strangle_cost': 0.8, 'upward_profit': 4.55612885484008, 'downward_profit': 2.4361261082580485, 'meets_criteria': True}
# {'call_strike': 52.0, 'put_strike': 50.0, 'call_price': 0.65, 'put_price': 0.19, 'strangle_cost': 0.8400000000000001, 'upward_profit': 4.51612885484008, 'downward_profit': 2.8961261082580485, 'meets_criteria': True}
# {'call_strike': 52.0, 'put_strike': 51.0, 'call_price': 0.65, 'put_price': 0.41, 'strangle_cost': 1.06, 'upward_profit': 4.296128854840079, 'downward_profit': 3.6761261082580483, 'meets_criteria': True}
# {'call_strike': 53.0, 'put_strike': 47.0, 'call_price': 0.29, 'put_price': 0.04, 'strangle_cost': 0.32999999999999996, 'upward_profit': 4.0261288548400795, 'downward_profit': 0.4061261082580484, 'meets_criteria': True}
# {'call_strike': 53.0, 'put_strike': 47.5, 'call_price': 0.29, 'put_price': 0.13, 'strangle_cost': 0.42, 'upward_profit': 3.9361288548400797, 'downward_profit': 0.8161261082580484, 'meets_criteria': True}
# {'call_strike': 53.0, 'put_strike': 48.0, 'call_price': 0.29, 'put_price': 0.06, 'strangle_cost': 0.35, 'upward_profit': 4.00612885484008, 'downward_profit': 1.3861261082580483, 'meets_criteria': True}
# {'call_strike': 53.0, 'put_strike': 48.5, 'call_price': 0.29, 'put_price': 0.1, 'strangle_cost': 0.39, 'upward_profit': 3.9661288548400795, 'downward_profit': 1.8461261082580482, 'meets_criteria': True}
# {'call_strike': 53.0, 'put_strike': 49.0, 'call_price': 0.29, 'put_price': 0.11, 'strangle_cost': 0.39999999999999997, 'upward_profit': 3.9561288548400797, 'downward_profit': 2.3361261082580485, 'meets_criteria': True}
# {'call_strike': 53.0, 'put_strike': 49.5, 'call_price': 0.29, 'put_price': 0.15, 'strangle_cost': 0.43999999999999995, 'upward_profit': 3.9161288548400797, 'downward_profit': 2.7961261082580484, 'meets_criteria': True}
# {'call_strike': 53.0, 'put_strike': 50.0, 'call_price': 0.29, 'put_price': 0.19, 'strangle_cost': 0.48, 'upward_profit': 3.8761288548400796, 'downward_profit': 3.2561261082580484, 'meets_criteria': True}
# {'call_strike': 53.0, 'put_strike': 51.0, 'call_price': 0.29, 'put_price': 0.41, 'strangle_cost': 0.7, 'upward_profit': 3.6561288548400794, 'downward_profit': 4.036126108258048, 'meets_criteria': True}
# {'call_strike': 54.0, 'put_strike': 47.0, 'call_price': 0.13, 'put_price': 0.04, 'strangle_cost': 0.17, 'upward_profit': 3.1861288548400797, 'downward_profit': 0.5661261082580483, 'meets_criteria': True}
# {'call_strike': 54.0, 'put_strike': 47.5, 'call_price': 0.13, 'put_price': 0.13, 'strangle_cost': 0.26, 'upward_profit': 3.09612885484008, 'downward_profit': 0.9761261082580484, 'meets_criteria': True}
# {'call_strike': 54.0, 'put_strike': 48.0, 'call_price': 0.13, 'put_price': 0.06, 'strangle_cost': 0.19, 'upward_profit': 3.1661288548400797, 'downward_profit': 1.5461261082580484, 'meets_criteria': True}
# {'call_strike': 54.0, 'put_strike': 48.5, 'call_price': 0.13, 'put_price': 0.1, 'strangle_cost': 0.23, 'upward_profit': 3.1261288548400796, 'downward_profit': 2.0061261082580484, 'meets_criteria': True}
# {'call_strike': 54.0, 'put_strike': 49.0, 'call_price': 0.13, 'put_price': 0.11, 'strangle_cost': 0.24, 'upward_profit': 3.1161288548400794, 'downward_profit': 2.496126108258048, 'meets_criteria': True}
# {'call_strike': 54.0, 'put_strike': 49.5, 'call_price': 0.13, 'put_price': 0.15, 'strangle_cost': 0.28, 'upward_profit': 3.0761288548400794, 'downward_profit': 2.956126108258048, 'meets_criteria': True}
# {'call_strike': 54.0, 'put_strike': 50.0, 'call_price': 0.13, 'put_price': 0.19, 'strangle_cost': 0.32, 'upward_profit': 3.0361288548400798, 'downward_profit': 3.4161261082580485, 'meets_criteria': True}
# {'call_strike': 54.0, 'put_strike': 51.0, 'call_price': 0.13, 'put_price': 0.41, 'strangle_cost': 0.54, 'upward_profit': 2.8161288548400796, 'downward_profit': 4.196126108258048, 'meets_criteria': True}
# {'call_strike': 55.0, 'put_strike': 47.0, 'call_price': 0.06, 'put_price': 0.04, 'strangle_cost': 0.1, 'upward_profit': 2.2561288548400795, 'downward_profit': 0.6361261082580484, 'meets_criteria': True}
# {'call_strike': 55.0, 'put_strike': 47.5, 'call_price': 0.06, 'put_price': 0.13, 'strangle_cost': 0.19, 'upward_profit': 2.1661288548400797, 'downward_profit': 1.0461261082580484, 'meets_criteria': True}
# {'call_strike': 55.0, 'put_strike': 48.0, 'call_price': 0.06, 'put_price': 0.06, 'strangle_cost': 0.12, 'upward_profit': 2.2361288548400795, 'downward_profit': 1.6161261082580483, 'meets_criteria': True}
# {'call_strike': 55.0, 'put_strike': 48.5, 'call_price': 0.06, 'put_price': 0.1, 'strangle_cost': 0.16, 'upward_profit': 2.1961288548400795, 'downward_profit': 2.076126108258048, 'meets_criteria': True}
# {'call_strike': 55.0, 'put_strike': 49.0, 'call_price': 0.06, 'put_price': 0.11, 'strangle_cost': 0.16999999999999998, 'upward_profit': 2.1861288548400797, 'downward_profit': 2.5661261082580484, 'meets_criteria': True}
# {'call_strike': 55.0, 'put_strike': 49.5, 'call_price': 0.06, 'put_price': 0.15, 'strangle_cost': 0.21, 'upward_profit': 2.1461288548400796, 'downward_profit': 3.0261261082580484, 'meets_criteria': True}
# {'call_strike': 55.0, 'put_strike': 50.0, 'call_price': 0.06, 'put_price': 0.19, 'strangle_cost': 0.25, 'upward_profit': 2.1061288548400796, 'downward_profit': 3.4861261082580484, 'meets_criteria': True}
# {'call_strike': 55.0, 'put_strike': 51.0, 'call_price': 0.06, 'put_price': 0.41, 'strangle_cost': 0.47, 'upward_profit': 1.8861288548400796, 'downward_profit': 4.266126108258049, 'meets_criteria': True}
# {'call_strike': 56.0, 'put_strike': 47.0, 'call_price': 0.05, 'put_price': 0.04, 'strangle_cost': 0.09, 'upward_profit': 1.2661288548400795, 'downward_profit': 0.6461261082580484, 'meets_criteria': True}
# {'call_strike': 56.0, 'put_strike': 47.5, 'call_price': 0.05, 'put_price': 0.13, 'strangle_cost': 0.18, 'upward_profit': 1.1761288548400797, 'downward_profit': 1.0561261082580484, 'meets_criteria': True}
# {'call_strike': 56.0, 'put_strike': 48.0, 'call_price': 0.05, 'put_price': 0.06, 'strangle_cost': 0.11, 'upward_profit': 1.2461288548400795, 'downward_profit': 1.6261261082580483, 'meets_criteria': True}
# {'call_strike': 56.0, 'put_strike': 48.5, 'call_price': 0.05, 'put_price': 0.1, 'strangle_cost': 0.15000000000000002, 'upward_profit': 1.2061288548400797, 'downward_profit': 2.0861261082580485, 'meets_criteria': True}
# {'call_strike': 56.0, 'put_strike': 49.0, 'call_price': 0.05, 'put_price': 0.11, 'strangle_cost': 0.16, 'upward_profit': 1.1961288548400797, 'downward_profit': 2.576126108258048, 'meets_criteria': True}
# {'call_strike': 56.0, 'put_strike': 49.5, 'call_price': 0.05, 'put_price': 0.15, 'strangle_cost': 0.2, 'upward_profit': 1.1561288548400797, 'downward_profit': 3.036126108258048, 'meets_criteria': True}
# {'call_strike': 56.0, 'put_strike': 50.0, 'call_price': 0.05, 'put_price': 0.19, 'strangle_cost': 0.24, 'upward_profit': 1.1161288548400796, 'downward_profit': 3.496126108258048, 'meets_criteria': True}
# {'call_strike': 56.0, 'put_strike': 51.0, 'call_price': 0.05, 'put_price': 0.41, 'strangle_cost': 0.45999999999999996, 'upward_profit': 0.8961288548400796, 'downward_profit': 4.276126108258048, 'meets_criteria': True}
# {'call_strike': 57.0, 'put_strike': 47.0, 'call_price': 0.02, 'put_price': 0.04, 'strangle_cost': 0.06, 'upward_profit': 0.2961288548400796, 'downward_profit': 0.6761261082580483, 'meets_criteria': True}
# {'call_strike': 57.0, 'put_strike': 47.5, 'call_price': 0.02, 'put_price': 0.13, 'strangle_cost': 0.15, 'upward_profit': 0.20612885484007962, 'downward_profit': 1.0861261082580485, 'meets_criteria': True}
# {'call_strike': 57.0, 'put_strike': 48.0, 'call_price': 0.02, 'put_price': 0.06, 'strangle_cost': 0.08, 'upward_profit': 0.2761288548400796, 'downward_profit': 1.6561261082580483, 'meets_criteria': True}
# {'call_strike': 57.0, 'put_strike': 48.5, 'call_price': 0.02, 'put_price': 0.1, 'strangle_cost': 0.12000000000000001, 'upward_profit': 0.23612885484007962, 'downward_profit': 2.1161261082580483, 'meets_criteria': True}
# {'call_strike': 57.0, 'put_strike': 49.0, 'call_price': 0.02, 'put_price': 0.11, 'strangle_cost': 0.13, 'upward_profit': 0.2261288548400796, 'downward_profit': 2.6061261082580485, 'meets_criteria': True}
# {'call_strike': 57.0, 'put_strike': 49.5, 'call_price': 0.02, 'put_price': 0.15, 'strangle_cost': 0.16999999999999998, 'upward_profit': 0.18612885484007963, 'downward_profit': 3.0661261082580484, 'meets_criteria': True}
# {'call_strike': 57.0, 'put_strike': 50.0, 'call_price': 0.02, 'put_price': 0.19, 'strangle_cost': 0.21, 'upward_profit': 0.14612885484007962, 'downward_profit': 3.5261261082580484, 'meets_criteria': True}
#
# Profitable Strangles for DG:
# {'call_strike': 77.0, 'put_strike': 55.0, 'call_price': 1.05, 'put_price': 0.38, 'strangle_cost': 1.4300000000000002, 'upward_profit': 25.613294730711594, 'downward_profit': 4.813291678953782, 'meets_criteria': True}
# {'call_strike': 77.0, 'put_strike': 60.0, 'call_price': 1.05, 'put_price': 0.02, 'strangle_cost': 1.07, 'upward_profit': 25.973294730711594, 'downward_profit': 10.173291678953781, 'meets_criteria': True}
# {'call_strike': 77.0, 'put_strike': 62.0, 'call_price': 1.05, 'put_price': 0.69, 'strangle_cost': 1.74, 'upward_profit': 25.303294730711595, 'downward_profit': 11.503291678953781, 'meets_criteria': True}
# {'call_strike': 77.0, 'put_strike': 63.0, 'call_price': 1.05, 'put_price': 0.31, 'strangle_cost': 1.36, 'upward_profit': 25.683294730711594, 'downward_profit': 12.883291678953782, 'meets_criteria': True}
# {'call_strike': 77.0, 'put_strike': 64.0, 'call_price': 1.05, 'put_price': 0.09, 'strangle_cost': 1.1400000000000001, 'upward_profit': 25.903294730711593, 'downward_profit': 14.10329167895378, 'meets_criteria': True}
# {'call_strike': 77.0, 'put_strike': 65.0, 'call_price': 1.05, 'put_price': 0.03, 'strangle_cost': 1.08, 'upward_profit': 25.963294730711596, 'downward_profit': 15.163291678953781, 'meets_criteria': True}
# {'call_strike': 77.0, 'put_strike': 66.0, 'call_price': 1.05, 'put_price': 0.02, 'strangle_cost': 1.07, 'upward_profit': 25.973294730711594, 'downward_profit': 16.17329167895378, 'meets_criteria': True}
# {'call_strike': 77.0, 'put_strike': 67.0, 'call_price': 1.05, 'put_price': 0.05, 'strangle_cost': 1.1, 'upward_profit': 25.943294730711592, 'downward_profit': 17.14329167895378, 'meets_criteria': True}
# {'call_strike': 77.0, 'put_strike':
 'meets_criteria': True}
# {'call_strike': 81.0, 'put_strike': 55.0, 'call_price': 0.15, 'put_price': 0.38, 'strangle_cost': 0.53, 'upward_profit': 22.513294730711593, 'downward_profit': 5.713291678953781, 'meets_criteria': True}
# {'call_strike': 81.0, 'put_strike': 60.0, 'call_price': 0.15, 'put_price': 0.02, 'strangle_cost': 0.16999999999999998, 'upward_profit': 22.873294730711592, 'downward_profit': 11.073291678953781, 'meets_criteria': True}
# {'call_strike': 81.0, 'put_strike': 62.0, 'call_price': 0.15, 'put_price': 0.69, 'strangle_cost': 0.84, 'upward_profit': 22.203294730711594, 'downward_profit': 12.403291678953781, 'meets_criteria': True}
# {'call_strike': 81.0, 'put_strike': 63.0, 'call_price': 0.15, 'put_price': 0.31, 'strangle_cost': 0.45999999999999996, 'upward_profit': 22.583294730711593, 'downward_profit': 13.78329167895378, 'meets_criteria': True}
# {'call_strike': 81.0, 'put_strike': 64.0, 'call_price': 0.15, 'put_price': 0.09, 'strangle_cost': 0.24, 'upward_profit': 22.803294730711595, 'downward_profit': 15.003291678953781, 'meets_criteria': True}
# {'call_strike': 81.0, 'put_strike': 65.0, 'call_price': 0.15, 'put_price': 0.03, 'strangle_cost': 0.18, 'upward_profit': 22.863294730711594, 'downward_profit': 16.06329167895378, 'meets_criteria': True}
# {'call_strike': 81.0, 'put_strike': 66.0, 'call_price': 0.15, 'put_price': 0.02, 'strangle_cost': 0.16999999999999998, 'upward_profit': 22.873294730711592, 'downward_profit': 17.07329167895378, 'meets_criteria': True}
# {'call_strike': 81.0, 'put_strike': 67.0, 'call_price': 0.15, 'put_price': 0.05, 'strangle_cost': 0.2, 'upward_profit': 22.843294730711595, 'downward_profit': 18.043291678953782, 'meets_criteria': True}
# {'call_strike': 81.0, 'put_strike': 68.0, 'call_price': 0.15, 'put_price': 0.05, 'strangle_cost': 0.2, 'upward_profit': 22.843294730711595, 'downward_profit': 19.043291678953782, 'meets_criteria': True}
# {'call_strike': 81.0, 'put_strike': 69.0, 'call_price': 0.15, 'put_price': 0.14, 'strangle_cost': 0.29000000000000004, 'upward_profit': 22.753294730711595, 'downward_profit': 19.953291678953782, 'meets_criteria': True}
# {'call_strike': 81.0, 'put_strike': 70.0, 'call_price': 0.15, 'put_price': 0.05, 'strangle_cost': 0.2, 'upward_profit': 22.843294730711595, 'downward_profit': 21.043291678953782, 'meets_criteria': True}
# {'call_strike': 81.0, 'put_strike': 71.0, 'call_price': 0.15, 'put_price': 0.1, 'strangle_cost': 0.25, 'upward_profit': 22.793294730711594, 'downward_profit': 21.99329167895378, 'meets_criteria': True}
# {'call_strike': 81.0, 'put_strike': 72.0, 'call_price': 0.15, 'put_price': 0.16, 'strangle_cost': 0.31, 'upward_profit': 22.733294730711595, 'downward_profit': 22.933291678953783, 'meets_criteria': True}
# ...
# {'call_strike': 160.0, 'put_strike': 142.0, 'call_price': 0.76, 'put_price': 0.32, 'strangle_cost': 1.08, 'upward_profit': 11.06367056404572, 'downward_profit': 7.2836717847488455, 'meets_criteria': True}
# {'call_strike': 160.0, 'put_strike': 143.0, 'call_price': 0.76, 'put_price': 0.47, 'strangle_cost': 1.23, 'upward_profit': 10.91367056404572, 'downward_profit': 8.133671784748845, 'meets_criteria': True}
# {'call_strike': 160.0, 'put_strike': 144.0, 'call_price': 0.76, 'put_price': 0.45, 'strangle_cost': 1.21, 'upward_profit': 10.93367056404572, 'downward_profit': 9.153671784748845, 'meets_criteria': True}
# {'call_strike': 160.0, 'put_strike': 145.0, 'call_price': 0.76, 'put_price': 0.66, 'strangle_cost': 1.42, 'upward_profit': 10.72367056404572, 'downward_profit': 9.943671784748846, 'meets_criteria': True}
# {'call_strike': 160.0, 'put_strike': 146.0, 'call_price': 0.76, 'put_price': 0.73, 'strangle_cost': 1.49, 'upward_profit': 10.65367056404572, 'downward_profit': 10.873671784748845, 'meets_criteria': True}
# {'call_strike': 160.0, 'put_strike': 147.0, 'call_price': 0.76, 'put_price': 0.88, 'strangle_cost': 1.6400000000000001, 'upward_profit': 10.50367056404572, 'downward_profit': 11.723671784748845, 'meets_criteria': True}
# {'call_strike': 160.0, 'put_strike': 148.0, 'call_price': 0.76, 'put_price': 0.99, 'strangle_cost': 1.75, 'upward_profit': 10.39367056404572, 'downward_profit': 12.613671784748846, 'meets_criteria': True}
# {'call_strike': 160.0, 'put_strike': 149.0, 'call_price': 0.76, 'put_price': 1.22, 'strangle_cost': 1.98, 'upward_profit': 10.16367056404572, 'downward_profit': 13.383671784748845, 'meets_criteria': True}
# {'call_strike': 160.0, 'put_strike': 150.0, 'call_price': 0.76, 'put_price': 1.47, 'strangle_cost': 2.23, 'upward_profit': 9.91367056404572, 'downward_profit': 14.133671784748845, 'meets_criteria': True}
# {'call_strike': 160.0, 'put_strike': 152.5, 'call_price': 0.76, 'put_price': 2.6, 'strangle_cost': 3.3600000000000003, 'upward_profit': 8.783670564045721, 'downward_profit': 15.503671784748846, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 135.0, 'call_price': 0.41, 'put_price': 0.21, 'strangle_cost': 0.62, 'upward_profit': 9.023670564045721, 'downward_profit': 0.7436717847488455, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 136.0, 'call_price': 0.41, 'put_price': 0.28, 'strangle_cost': 0.69, 'upward_profit': 8.953670564045721, 'downward_profit': 1.6736717847488456, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 137.0, 'call_price': 0.41, 'put_price': 0.17, 'strangle_cost': 0.58, 'upward_profit': 9.06367056404572, 'downward_profit': 2.7836717847488455, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 138.0, 'call_price': 0.41, 'put_price': 0.18, 'strangle_cost': 0.59, 'upward_profit': 9.05367056404572, 'downward_profit': 3.7736717847488457, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 139.0, 'call_price': 0.41, 'put_price': 0.2, 'strangle_cost': 0.61, 'upward_profit': 9.033670564045721, 'downward_profit': 4.753671784748845, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 140.0, 'call_price': 0.41, 'put_price': 0.24, 'strangle_cost': 0.6499999999999999, 'upward_profit': 8.99367056404572, 'downward_profit': 5.713671784748845, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 141.0, 'call_price': 0.41, 'put_price': 0.3, 'strangle_cost': 0.71, 'upward_profit': 8.93367056404572, 'downward_profit': 6.653671784748846, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 142.0, 'call_price': 0.41, 'put_price': 0.32, 'strangle_cost': 0.73, 'upward_profit': 8.91367056404572, 'downward_profit': 7.633671784748845, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 143.0, 'call_price': 0.41, 'put_price': 0.47, 'strangle_cost': 0.8799999999999999, 'upward_profit': 8.763670564045722, 'downward_profit': 8.483671784748847, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 144.0, 'call_price': 0.41, 'put_price': 0.45, 'strangle_cost': 0.86, 'upward_profit': 8.783670564045721, 'downward_profit': 9.503671784748846, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 145.0, 'call_price': 0.41, 'put_price': 0.66, 'strangle_cost': 1.07, 'upward_profit': 8.57367056404572, 'downward_profit': 10.293671784748845, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 146.0, 'call_price': 0.41, 'put_price': 0.73, 'strangle_cost': 1.14, 'upward_profit': 8.50367056404572, 'downward_profit': 11.223671784748845, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 147.0, 'call_price': 0.41, 'put_price': 0.88, 'strangle_cost': 1.29, 'upward_profit': 8.353670564045721, 'downward_profit': 12.073671784748846, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 148.0, 'call_price': 0.41, 'put_price': 0.99, 'strangle_cost': 1.4, 'upward_profit': 8.24367056404572, 'downward_profit': 12.963671784748845, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 149.0, 'call_price': 0.41, 'put_price': 1.22, 'strangle_cost': 1.63, 'upward_profit': 8.013670564045722, 'downward_profit': 13.733671784748847, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 150.0, 'call_price': 0.41, 'put_price': 1.47, 'strangle_cost': 1.88, 'upward_profit': 7.763670564045721, 'downward_profit': 14.483671784748847, 'meets_criteria': True}
# {'call_strike': 162.5, 'put_strike': 152.5, 'call_price': 0.41, 'put_price': 2.6, 'strangle_cost': 3.0100000000000002, 'upward_profit': 6.633670564045721, 'downward_profit': 15.853671784748846, 'meets_criteria': True}
# {'call_strike': 165.0, 'put_strike':
 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 138.0, 'call_price': 0.17, 'put_price': 0.18, 'strangle_cost': 0.35, 'upward_profit': 4.293670564045721, 'downward_profit': 4.013671784748846, 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 139.0, 'call_price': 0.17, 'put_price': 0.2, 'strangle_cost': 0.37, 'upward_profit': 4.27367056404572, 'downward_profit': 4.993671784748845, 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 140.0, 'call_price': 0.17, 'put_price': 0.24, 'strangle_cost': 0.41000000000000003, 'upward_profit': 4.23367056404572, 'downward_profit': 5.953671784748845, 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 141.0, 'call_price': 0.17, 'put_price': 0.3, 'strangle_cost': 0.47, 'upward_profit': 4.173670564045721, 'downward_profit': 6.893671784748846, 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 142.0, 'call_price': 0.17, 'put_price': 0.32, 'strangle_cost': 0.49, 'upward_profit': 4.15367056404572, 'downward_profit': 7.873671784748845, 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 143.0, 'call_price': 0.17, 'put_price': 0.47, 'strangle_cost': 0.64, 'upward_profit': 4.003670564045721, 'downward_profit': 8.723671784748845, 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 144.0, 'call_price': 0.17, 'put_price': 0.45, 'strangle_cost': 0.62, 'upward_profit': 4.02367056404572, 'downward_profit': 9.743671784748846, 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 145.0, 'call_price': 0.17, 'put_price': 0.66, 'strangle_cost': 0.8300000000000001, 'upward_profit': 3.8136705640457205, 'downward_profit': 10.533671784748845, 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 146.0, 'call_price': 0.17, 'put_price': 0.73, 'strangle_cost': 0.9, 'upward_profit': 3.7436705640457206, 'downward_profit': 11.463671784748845, 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 147.0, 'call_price': 0.17, 'put_price': 0.88, 'strangle_cost': 1.05, 'upward_profit': 3.5936705640457207, 'downward_profit': 12.313671784748845, 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 148.0, 'call_price': 0.17, 'put_price': 0.99, 'strangle_cost': 1.16, 'upward_profit': 3.4836705640457204, 'downward_profit': 13.203671784748845, 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 149.0, 'call_price': 0.17, 'put_price': 1.22, 'strangle_cost': 1.39, 'upward_profit': 3.253670564045721, 'downward_profit': 13.973671784748845, 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 150.0, 'call_price': 0.17, 'put_price': 1.47, 'strangle_cost': 1.64, 'upward_profit': 3.003670564045721, 'downward_profit': 14.723671784748845, 'meets_criteria': True}
# {'call_strike': 167.5, 'put_strike': 152.5, 'call_price': 0.17, 'put_price': 2.6, 'strangle_cost': 2.77, 'upward_profit': 1.8736705640457205, 'downward_profit': 16.093671784748846, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 135.0, 'call_price': 0.11, 'put_price': 0.21, 'strangle_cost': 0.32, 'upward_profit': 1.8236705640457205, 'downward_profit': 1.0436717847488455, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 136.0, 'call_price': 0.11, 'put_price': 0.28, 'strangle_cost': 0.39, 'upward_profit': 1.7536705640457204, 'downward_profit': 1.9736717847488454, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 137.0, 'call_price': 0.11, 'put_price': 0.17, 'strangle_cost': 0.28, 'upward_profit': 1.8636705640457205, 'downward_profit': 3.0836717847488453, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 138.0, 'call_price': 0.11, 'put_price': 0.18, 'strangle_cost': 0.29, 'upward_profit': 1.8536705640457205, 'downward_profit': 4.0736717847488455, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 139.0, 'call_price': 0.11, 'put_price': 0.2, 'strangle_cost': 0.31, 'upward_profit': 1.8336705640457205, 'downward_profit': 5.053671784748846, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 140.0, 'call_price': 0.11, 'put_price': 0.24, 'strangle_cost': 0.35, 'upward_profit': 1.7936705640457205, 'downward_profit': 6.013671784748846, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 141.0, 'call_price': 0.11, 'put_price': 0.3, 'strangle_cost': 0.41, 'upward_profit': 1.7336705640457206, 'downward_profit': 6.953671784748845, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 142.0, 'call_price': 0.11, 'put_price': 0.32, 'strangle_cost': 0.43, 'upward_profit': 1.7136705640457206, 'downward_profit': 7.933671784748846, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 143.0, 'call_price': 0.11, 'put_price': 0.47, 'strangle_cost': 0.58, 'upward_profit': 1.5636705640457205, 'downward_profit': 8.783671784748845, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 144.0, 'call_price': 0.11, 'put_price': 0.45, 'strangle_cost': 0.56, 'upward_profit': 1.5836705640457205, 'downward_profit': 9.803671784748845, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 145.0, 'call_price': 0.11, 'put_price': 0.66, 'strangle_cost': 0.77, 'upward_profit': 1.3736705640457205, 'downward_profit': 10.593671784748846, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 146.0, 'call_price': 0.11, 'put_price': 0.73, 'strangle_cost': 0.84, 'upward_profit': 1.3036705640457207, 'downward_profit': 11.523671784748846, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 147.0, 'call_price': 0.11, 'put_price': 0.88, 'strangle_cost': 0.99, 'upward_profit': 1.1536705640457205, 'downward_profit': 12.373671784748845, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 148.0, 'call_price': 0.11, 'put_price': 0.99, 'strangle_cost': 1.1, 'upward_profit': 1.0436705640457205, 'downward_profit': 13.263671784748846, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 149.0, 'call_price': 0.11, 'put_price': 1.22, 'strangle_cost': 1.33, 'upward_profit': 0.8136705640457205, 'downward_profit': 14.033671784748845, 'meets_criteria': True}
# {'call_strike': 170.0, 'put_strike': 150.0, 'call_price': 0.11, 'put_price': 1.47, 'strangle_cost': 1.58, 'upward_profit': 0.5636705640457205, 'downward_profit': 14.783671784748845, 'meets_criteria': True}

# %%
# find the most profitable strangle for each ticker
most_profitable_strangles = {}

for ticker, strangles in profitable_strangles.items():
    # sort the strangles by the maximum of upward or downward profit
    max_profit_strangle = max(strangles, 
                            key=lambda x: max(x['upward_profit'], x['downward_profit']))
    most_profitable_strangles[ticker] = max_profit_strangle

pd.DataFrame.from_dict(most_profitable_strangles, orient='index')
# Out:
#       call_strike  put_strike  call_price  put_price  strangle_cost  \
# EBAY         70.0        65.0        0.03       0.74           0.77
# EXPE        185.0       175.0        2.46       0.18           2.64
# GM           52.0        47.0        0.65       0.04           0.69
# DG           90.0        76.0        0.01       1.05           1.06
# AXP         325.0       297.5        0.03       2.82           2.85
# FIS          82.0        77.0        0.53       0.15           0.68
# GS          625.0       565.0        0.05       5.75           5.80
# MS          133.0       123.0        0.02       1.30           1.32
# BIIB        147.0       140.0        1.90       0.32           2.22
# LMT         490.0       450.0        3.00       0.05           3.05
# AMD         133.0       119.0        0.11       2.15           2.26
# MU          104.0        90.0        0.05       1.70           1.75
# QCOM        167.5       152.5        0.17       2.60           2.77
#
#       upward_profit  downward_profit  meets_criteria
# EBAY       1.664117         6.644113            True
# EXPE      17.184569         7.684569            True
# GM         4.666129         0.046126            True
# DG        12.983295        26.183292            True
# AXP        2.285959        27.485972            True
# FIS        7.420286         3.500288            True
# GS         1.500847        59.300896            True
# MS         2.807058        11.927053            True
# BIIB      24.685538        18.745536            True
# LMT       51.878071        13.838093            True
# AMD        1.420208        15.000209            True
# MU         1.205495        14.965489            True
# QCOM       1.873671        16.093672            True
